# %% [markdown]
# # Agenda
#
# 1. Scoping -- LEGB
# 2. Inner functions
# 3. Dispatch tables
# 4. Comprehensions
# 5. Functions as arguments
# 6. `lambda`

# %% [markdown]
# # Scoping

# %%
x = 100

for i in range(10):
    x = i ** 2

print(x)
# Out:
# 81
